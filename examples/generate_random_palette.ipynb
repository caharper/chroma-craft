# %%
import numpy as np
import chroma_craft as cc

# %%
colors = cc.generate_palette(3, distance=80, color_format="rgb", seed=11)
cc.visualize_palette(colors, show=True)

# %%
colors = cc.generate_palette_with_base(
    np.array([66.0, 128.0, 99.0]), 15, distance=50, color_format="rgb", seed=37
)

# %%
cc.visualize_palette(colors, show=True)
